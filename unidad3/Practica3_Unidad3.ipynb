# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpastrana806-lab/Probabilidad-y-estadistica/blob/main/unidad3/Practica3_Unidad3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# # **Probabilidad y estadística**
#
# ## Unidad 3
#
# ### Varianza y desviacion estandar (ejemplo en Python)
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno: Cesar Guillermo Pastrana Canales

# %%
import math

x= [5, 6, 7, 8, 9, 10]
p= [0.05, 0.10, 0.20, 0.30, 0.25, 0.10]

#Calcular E(X)
esperanza = 0
for i in range (len(x)):
  esperanza +=x[i] * p[i]

  # Calcular E(x^2)
  esperanza_cuadrado = 0
  for i in range(len(x)):
    esperanza_cuadrado += (x[i] **2) * p[i]

# Calcular varianza y desvidesviacion estandar
varianza = esperanza_cuadrado - esperanza ** 2
desviacion = math.sqrt(varianza)
# Mostrar resultados
print(f"E(X) = esperanza:.2f)")
print(f"E(X^2) = esperanza_ cuadrado:.2f)")
print(f"Varianza = (varianza:.2f]")
print(f"Desviación estándar = desviacion:.2fI")
# Out:
# E(X) = esperanza:.2f)
# E(X^2) = esperanza_ cuadrado:.2f)
# Varianza = (varianza:.2f]
# Desviación estándar = desviacion:.2fI
