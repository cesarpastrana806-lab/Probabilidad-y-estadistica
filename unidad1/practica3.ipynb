# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpastrana806-lab/Probabilidad-y-estadistica/blob/main/unidad1/practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![image](https://github.com/JoseGabriel-ITD/Probabilidad-y-Estadistica/blob/main/Cintilla2004.png?raw=true)
#
# # **Probabilidad y estadística**
#
# ## Unidad 1
#
# ### Practica 3. Tabla de frecuencias y regla de sturges
#
# ### Facilitador: *Dr. José Gabriel Rodríguez Rivas*
#
# ### Alumno: Cesar Guillermo Pastrana Canales

# %%
# basado en el LIBRO estadística para administración pagina 12
# creamos una lista vacía que representa la edad de 100 personas
import random
edades = []
# Hacemos un ciclo para generar 100 numeros aleatorios que representan la edad de las personas
for i in range(100):
    # generamos un numero aleatorio con la funcion randint y lo guardamos en la variable numero_aleatorio
    numero_aleatorio = random.randint(18, 70)
    # Agregamos el numero aleatorio a la lista de valores
    edades.append(numero_aleatorio)
print(edades)
# Out:
# [34, 25, 50, 66, 57, 58, 22, 33, 32, 19, 53, 26, 68, 51, 27, 61, 19, 47, 30, 58, 65, 65, 52, 50, 66, 18, 63, 29, 59, 42, 49, 59, 23, 59, 29, 41, 54, 57, 40, 62, 55, 57, 21, 27, 58, 54, 26, 41, 32, 28, 26, 48, 62, 33, 56, 29, 47, 22, 52, 59, 30, 27, 38, 35, 58, 70, 54, 58, 34, 34, 52, 70, 37, 50, 38, 56, 51, 38, 19, 33, 50, 53, 25, 44, 18, 19, 35, 25, 70, 66, 21, 51, 65, 38, 32, 44, 58, 60, 53, 58]

# %%
import pandas as pd

# Crear un DataFrame de pandas con los números aleatorios
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    34
# 1    25
# 2    50
# 3    66
# 4    57

# %%
# Calcular la tabla de distribución de frecuencias
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')

# Imprimir la tabla de distribución de frecuencias
print("Tabla de Distribución de Frecuencias:")
tabla_frecuencias
# Out:
# Tabla de Distribución de Frecuencias:
#     Edad  Frecuencia
# 21    18           2
# 2     19           4
# 28    21           2
# 20    22           2
# 36    23           1
# 8     25           3
# 17    26           3
# 18    27           3
# 38    28           1
# 15    29           3
# 23    30           2
# 11    32           3
# 7     33           3
# 5     34           3
# 27    35           2
# 40    37           1
# 4     38           4
# 37    40           1
# 22    41           2
# 31    42           1
# 26    44           2
# 24    47           2
# 39    48           1
# 34    49           1
# 1     50           4
# 12    51           3
# 14    52           3
# 13    53           3
# 10    54           3
# 35    55           1
# 25    56           2
# 6     57           3
# 0     58           7
# 3     59           4
# 41    60           1
# 33    61           1
# 29    62           2
# 32    63           1
# 16    65           3
# 9     66           3
# 30    68           1
# 19    70           3

# %%
tabla_frecuencias["Frecuencia Relativa"] = tabla_frecuencias["Frecuencia"] / 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa
# 21    18           2                 0.02
# 2     19           4                 0.04
# 28    21           2                 0.02
# 20    22           2                 0.02
# 36    23           1                 0.01
# 8     25           3                 0.03
# 17    26           3                 0.03
# 18    27           3                 0.03
# 38    28           1                 0.01
# 15    29           3                 0.03
# 23    30           2                 0.02
# 11    32           3                 0.03
# 7     33           3                 0.03
# 5     34           3                 0.03
# 27    35           2                 0.02
# 40    37           1                 0.01
# 4     38           4                 0.04
# 37    40           1                 0.01
# 22    41           2                 0.02
# 31    42           1                 0.01
# 26    44           2                 0.02
# 24    47           2                 0.02
# 39    48           1                 0.01
# 34    49           1                 0.01
# 1     50           4                 0.04
# 12    51           3                 0.03
# 14    52           3                 0.03
# 13    53           3                 0.03
# 10    54           3                 0.03
# 35    55           1                 0.01
# 25    56           2                 0.02
# 6     57           3                 0.03
# 0     58           7                 0.07
# 3     59           4                 0.04
# 41    60           1                 0.01
# 33    61           1                 0.01
# 29    62           2                 0.02
# 32    63           1                 0.01
# 16    65           3                 0.03
# 9     66           3                 0.03
# 30    68           1                 0.01
# 19    70           3                 0.03

# %%
tabla_frecuencias["Fre Porcentaje"] = tabla_frecuencias["Frecuencia"] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frecuencia Relativa  Fre Porcentaje
# 21    18           2                 0.02             2.0
# 2     19           4                 0.04             4.0
# 28    21           2                 0.02             2.0
# 20    22           2                 0.02             2.0
# 36    23           1                 0.01             1.0
# 8     25           3                 0.03             3.0
# 17    26           3                 0.03             3.0
# 18    27           3                 0.03             3.0
# 38    28           1                 0.01             1.0
# 15    29           3                 0.03             3.0
# 23    30           2                 0.02             2.0
# 11    32           3                 0.03             3.0
# 7     33           3                 0.03             3.0
# 5     34           3                 0.03             3.0
# 27    35           2                 0.02             2.0
# 40    37           1                 0.01             1.0
# 4     38           4                 0.04             4.0
# 37    40           1                 0.01             1.0
# 22    41           2                 0.02             2.0
# 31    42           1                 0.01             1.0
# 26    44           2                 0.02             2.0
# 24    47           2                 0.02             2.0
# 39    48           1                 0.01             1.0
# 34    49           1                 0.01             1.0
# 1     50           4                 0.04             4.0
# 12    51           3                 0.03             3.0
# 14    52           3                 0.03             3.0
# 13    53           3                 0.03             3.0
# 10    54           3                 0.03             3.0
# 35    55           1                 0.01             1.0
# 25    56           2                 0.02             2.0
# 6     57           3                 0.03             3.0
# 0     58           7                 0.07             7.0
# 3     59           4                 0.04             4.0
# 41    60           1                 0.01             1.0
# 33    61           1                 0.01             1.0
# 29    62           2                 0.02             2.0
# 32    63           1                 0.01             1.0
# 16    65           3                 0.03             3.0
# 9     66           3                 0.03             3.0
# 30    68           1                 0.01             1.0
# 19    70           3                 0.03             3.0

# %%
tabla_frecuencias["Frecuencia Acumulada"] = tabla_frecuencias["Frecuencia"].cumsum()

# %%
# Importamos la librería math de funciones matemáticas
import math
# Volvemos a usar la lista edades
print(edades)
# Out:
# [34, 25, 50, 66, 57, 58, 22, 33, 32, 19, 53, 26, 68, 51, 27, 61, 19, 47, 30, 58, 65, 65, 52, 50, 66, 18, 63, 29, 59, 42, 49, 59, 23, 59, 29, 41, 54, 57, 40, 62, 55, 57, 21, 27, 58, 54, 26, 41, 32, 28, 26, 48, 62, 33, 56, 29, 47, 22, 52, 59, 30, 27, 38, 35, 58, 70, 54, 58, 34, 34, 52, 70, 37, 50, 38, 56, 51, 38, 19, 33, 50, 53, 25, 44, 18, 19, 35, 25, 70, 66, 21, 51, 65, 38, 32, 44, 58, 60, 53, 58]

# %%
# Crear un DataFrame con las edades
df = pd.DataFrame({'Edad': edades})
df
# Out:
#     Edad
# 0     34
# 1     25
# 2     50
# 3     66
# 4     57
# ..   ...
# 95    44
# 96    58
# 97    60
# 98    53
# 99    58
#
# [100 rows x 1 columns]

# %%
# Calcular el número de intervalos utilizando la regla de Sturges
n = len(edades)
K = int(1 + math.log2(n))

print("Valor de n = ", n, "\nNúmero de intervalos = ", K)
# Crear la tabla de frecuencia
# Out:
# Valor de n =  100
# Número de intervalos =  7

# %%
 #Crear la tabla de frecuencia

tabla_frecuencia = pd.cut(df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (55.143, 62.571]    20
# 1  (47.714, 55.143]    19
# 2  (25.429, 32.857]    15
# 3  (32.857, 40.286]    14
# 4  (17.947, 25.429]    14
# 5    (62.571, 70.0]    11
# 6  (40.286, 47.714]     7

# %%
# Ordenar la tabla de frecuencia por el intervalo
tabla_frecuencia = tabla_frecuencia.sort_values(by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 4  (17.947, 25.429]    14
# 2  (25.429, 32.857]    15
# 3  (32.857, 40.286]    14
# 6  (40.286, 47.714]     7
# 1  (47.714, 55.143]    19
# 0  (55.143, 62.571]    20
# 5    (62.571, 70.0]    11

# %%
# Generar columnas siguientes
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] / n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

# Mostrar la tabla de frecuencia
print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Rel Ac  Frec Porc Ac
# 4  (17.947, 25.429]    14      0.14       14.0         0.14          14.0
# 2  (25.429, 32.857]    15      0.15       15.0         0.29          29.0
# 3  (32.857, 40.286]    14      0.14       14.0         0.43          43.0
# 6  (40.286, 47.714]     7      0.07        7.0         0.50          50.0
# 1  (47.714, 55.143]    19      0.19       19.0         0.69          69.0
# 0  (55.143, 62.571]    20      0.20       20.0         0.89          89.0
# 5    (62.571, 70.0]    11      0.11       11.0         1.00         100.0

# %%
import matplotlib.pyplot as plt

plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la función de matplotlib con valores estándar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la función de matplotlib con valores estándar')

# %%
# Crear un histograma basado en la tabla de frecuencia
plt.hist(df['Edad'], bins=K, alpha=0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
