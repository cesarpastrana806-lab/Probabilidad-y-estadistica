# %% [markdown]
# <a href="https://colab.research.google.com/github/cesarpastrana806-lab/Probabilidad-y-estadistica/blob/main/unidad5/preguntas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Interpretación del coeficiente de regresión
# Explica la relación entre el tiempo de estudio y las calificaciones finales:
# Grupo 1: Por cada hora adicional de estudio, la calificación final aumenta aproximadamente 1.84 puntos. Esto indica un impacto positivo y considerable.
# Grupo 2: Por cada hora adicional de estudio, la calificación final aumenta aproximadamente 0.70 puntos, lo que representa un impacto moderado.
# Grupo 3: Por cada hora adicional de estudio, la calificación final aumenta apenas 0.16 puntos, lo que sugiere un impacto casi nulo.
# 2. Interpretación del coeficiente de correlación
# Describe la fuerza y dirección de la relación entre las variables:
# Grupo 1: Relación lineal positiva muy fuerte. Las horas de estudio se correlacionan fuertemente con las calificaciones finales.
# Grupo 2: Relación lineal moderada. Se observa una relación más débil entre las horas de estudio y las calificaciones.
# Grupo 3: Relación casi nula. No hay una correlación lineal significativa entre las variables.
# 3. Significancia estadística del modelo de regresión
# ¿Es confiable el modelo para predecir las calificaciones finales según el tiempo de estudio?
# Grupo 1: Modelo muy confiable.
# Grupo 2: Modelo con confiabilidad baja.
# Grupo 3: Modelo no confiable.
